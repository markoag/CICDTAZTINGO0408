# %% [markdown]
# ## Grants - Proyecto Final
# Sigue el mismo patrón que tu `5.Grants_Medallion` de prueba: sentencias
# `GRANT` directas por `%sql`. Ajusta los correos/grupos
# (`analista1@hotmail.com`, `Devops`, etc.) a los principals reales de tu
# workspace.

# %%
# %sql
GRANT USE CATALOG ON CATALOG catalog_proyecto_final TO `analista1@hotmail.com`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_proyecto_final.bronze TO `analista1@hotmail.com`;

GRANT USE SCHEMA ON SCHEMA catalog_proyecto_final.bronze TO `Data Analysts`;

# %%
# %sql
GRANT USE SCHEMA ON SCHEMA catalog_proyecto_final.silver TO `dev1@hotmail.com`;

GRANT USE SCHEMA ON SCHEMA catalog_proyecto_final.silver TO `Devops`;

# %%
# %sql
GRANT CREATE TABLE ON SCHEMA catalog_proyecto_final.bronze TO `admin2@hotmail.com`;

# %%
# %sql
GRANT SELECT ON TABLE catalog_proyecto_final.bronze.ecommerce_sales_raw TO `analista2@hotmail.com`;
GRANT SELECT ON TABLE catalog_proyecto_final.bronze.aisles TO `dev2@hotmail.com`;
GRANT SELECT ON TABLE catalog_proyecto_final.bronze.departments TO `analista3@hotmail.com`;
GRANT SELECT ON TABLE catalog_proyecto_final.bronze.orders TO `analista1@hotmail.com`;
GRANT SELECT ON TABLE catalog_proyecto_final.bronze.products TO `dev1@hotmail.com`;
GRANT SELECT ON TABLE catalog_proyecto_final.bronze.order_products_prior TO `analista2@hotmail.com`;
GRANT SELECT ON TABLE catalog_proyecto_final.bronze.order_products_train TO `devops1@hotmail.com`;

# %%
# %sql
GRANT USE CATALOG ON CATALOG catalog_proyecto_final TO `Developers`;
GRANT USE SCHEMA ON SCHEMA catalog_proyecto_final.golden TO `Developers`;
GRANT USE CATALOG ON CATALOG catalog_proyecto_final TO `Data Analysts`;
GRANT USE SCHEMA ON SCHEMA catalog_proyecto_final.golden TO `Data Analysts`;
GRANT USE CATALOG ON CATALOG catalog_proyecto_final TO `Devops`;
GRANT USE SCHEMA ON SCHEMA catalog_proyecto_final.golden TO `Devops`;
GRANT SELECT ON TABLE catalog_proyecto_final.golden.kpi_ventas_ecommerce TO `Developers`;
GRANT SELECT ON TABLE catalog_proyecto_final.golden.kpi_pedidos_por_departamento_aisle TO `Data Analysts`;
GRANT SELECT ON TABLE catalog_proyecto_final.golden.kpi_tasa_recompra_producto TO `Devops`;
